# %% [markdown]
# ## Read CSV about items with Supermarket

# %%
import pandas as pd

songs_df = pd.read_csv("../datas/Top5000.csv")
songs_df.columns
# Out:
# Index(['Unnamed: 0', 'ars_name', 'rel_date', 'gens', 'descs', 'avg_rat',
#        'num_rat', 'num_revs', 'album', 'acousticness', 'danceability',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
songs_df['gens']
# Out:
# 0                            Alternative Rock, Art Rock
# 1                            Progressive Rock, Art Rock
# 2                            Progressive Rock, Art Rock
# 3               Art Rock, Experimental Rock, Electronic
# 4       Conscious Hip Hop, West Coast Hip Hop, Jazz Rap
#                              ...
# 4397           Singer/Songwriter, Roots Rock, Americana
# 4398                              Crust Punk, Metalcore
# 4399                   Progressive Rock, Symphonic Prog
# 4400                                           Art Rock
# 4401                              Smooth Soul, Pop Soul
# Name: gens, Length: 4402, dtype: object

# %%
for song, songs in enumerate(songs_df['gens']):
    if 'Rock' in songs:
        playlist = {
            "Banda": songs_df['ars_name'][song],
            "Album": songs_df['album'][song]
        }
        print(playlist)
# Out:
# {'Banda': 'Radiohead', 'Album': 'OK Computer'}
# {'Banda': 'Pink Floyd', 'Album': 'Wish You Were Here'}
# {'Banda': 'King Crimson', 'Album': 'In the Court of the Crimson King'}
# {'Banda': 'Radiohead', 'Album': 'Kid A'}
# {'Banda': 'Pink Floyd', 'Album': 'The Dark Side of the Moon'}
# {'Banda': 'The Beatles', 'Album': 'Abbey Road'}
# {'Banda': 'The Velvet Underground & Nico', 'Album': 'The Velvet Underground & Nico'}
# {'Banda': 'David Bowie', 'Album': 'The Rise and Fall of Ziggy Stardust and the Spiders From Mars'}
# {'Banda': 'The Beatles', 'Album': 'Revolver'}
# {'Banda': 'Radiohead', 'Album': 'In Rainbows'}
# {'Banda': 'Black Sabbath', 'Album': 'Paranoid'}
# {'Banda': 'Neutral Milk Hotel', 'Album': 'In the Aeroplane Over the Sea'}
# {'Banda': 'The Beatles', 'Album': "Sgt. Pepper's Lonely Hearts Club Band"}
# {'Banda': 'King Crimson', 'Album': 'Red'}
# {'Banda': 'Slint', 'Album': 'Spiderland'}
# {'Banda': 'The Cure', 'Album': 'Disintegration'}
# ...
